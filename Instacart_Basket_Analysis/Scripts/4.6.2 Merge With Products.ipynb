# %% [markdown]
# # Merging Data

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Assigning $PATH$
path = r'/Users/josephadamski/Instacart Basket Analysis'

# %%
# Import orders_product_prior.csv
df_ords_ = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'orders_products_prior.csv'), index_col=False)

# %%
# Verify Output
df_ords_prior.head()

# %%
df_ords=pd.read_csv(os.path.join(path, 'Data','Prepared Data', 'orders_checked.csv'),index_col=False)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_order_flag
# 0                     NaN              True
# 1                    15.0             False
# 2                    21.0             False
# 3                    29.0             False
# 4                    28.0             False

# %%
# Check Shape 
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
# Merge Data
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
# Values in merged column
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Shape of Merged Data
df_merged_large.shape
# Out:
# (32434489, 11)

# %% [markdown]
# ## Export to PKL

# %%
# Export to PKL
df_merged_large.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_combined.pkl'))
