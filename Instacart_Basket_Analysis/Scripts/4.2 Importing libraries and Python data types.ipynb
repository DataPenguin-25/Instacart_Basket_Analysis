# %% [markdown]
# #01.Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #02.Task 4.2

# %%
x = 50

# %%
y = 50

# %%
x + y
# Out:
# 100

# %%
z = 150

# %%
z - y
# Out:
# 100

# %%
a = 25

# %%
a + a + a + a
# Out:
# 100

# %%
r = 2.67

# %%
t = 5.895

# %%
t / r
# Out:
# 2.2078651685393256

# %%
j = 'test'

# %%
p = 'script'

# %%
j + p
# Out:
# 'testscript'

# %%
f = 'Python is better than excel. '

# %%
e = 'Yes, I agree.'

# %%
f + e
# Out:
# 'Python is better than excel. Yes, I agree.'
